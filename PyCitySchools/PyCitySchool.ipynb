# %%
import pandas as pd
import numpy as np

# %%
schoolfile = ("Resources/schools_complete.csv")
studentfile = ("Resources/students_complete.csv")

# %%
school_df = pd.read_csv(schoolfile)
school_df.head()
# Out:
#    School ID                   name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
student_df = pd.read_csv(studentfile)
student_df.head()
# Out:
#    Student ID               name gender grade             school  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#District Summary

Total_schools =school_df['name'].count()
Total_schools
# Out:
# 15

# %%
Total_students = student_df['name'].count()
Total_students
# Out:
# 39170

# %%
Total_budget = school_df['budget'].sum()
Total_budget
# Out:
# 24649428

# %%
avg_math = student_df['math_score'].mean()
avg_math
# Out:
# 78.98537145774827

# %%
avg_read = student_df['reading_score'].mean()
avg_read
# Out:
# 81.87784018381414

# %%
# % Passing Math, Assume 70 is passing

passmath= student_df['math_score']>=70
pass_math_count = passmath.value_counts(True)
pass_math_count[True]
pct_math_count = str(pass_math_count[True]*100)+"%"
pct_math_count
# Out:
# '74.9808526933878%'

# %%
# % Passing Reading, Assume 70 is passing

passread=student_df['reading_score']>=70
pass_read_count = passread.value_counts(True)
pass_read_count[True]
pct_read_count = str(pass_read_count[True]*100)+"%"
pct_read_count
# Out:
# '85.80546336482001%'

# %%
overall_pass = (pass_math_count+pass_read_count)/2
overall_pass[True]
pct_overall_pass = str(overall_pass[True]*100)+"%"
pct_overall_pass
# Out:
# '80.3931580291039%'

# %%
#District Summary 

column_name =["Total Schools","Total Students","Total Budget","Average Math Score","Average Reading School","% Passing Math","% Passing Reading","%Overall Passing Rate"]
columns = [Total_schools,Total_students,Total_budget,avg_math,avg_read,pct_math_count,pct_read_count,pct_overall_pass]

district = pd.DataFrame(columns,column_name).T
district
# Out:
#   Total Schools Total Students Total Budget Average Math Score  \
# 0            15          39170     24649428            78.9854
#
#   Average Reading School     % Passing Math   % Passing Reading  \
# 0                81.8778  74.9808526933878%  85.80546336482001%
#
#   %Overall Passing Rate
# 0     80.3931580291039%

# %%
#School Summary

school_summary = school_df[["name","type","size","budget"]]
school_summary
# Out:
#                      name      type  size   budget
# 0       Huang High School  District  2917  1910635
# 1    Figueroa High School  District  2949  1884411
# 2     Shelton High School   Charter  1761  1056600
# 3   Hernandez High School  District  4635  3022020
# 4     Griffin High School   Charter  1468   917500
# 5      Wilson High School   Charter  2283  1319574
# 6     Cabrera High School   Charter  1858  1081356
# 7      Bailey High School  District  4976  3124928
# 8      Holden High School   Charter   427   248087
# 9        Pena High School   Charter   962   585858
# 10     Wright High School   Charter  1800  1049400
# 11  Rodriguez High School  District  3999  2547363
# 12    Johnson High School  District  4761  3094650
# 13       Ford High School  District  2739  1763916
# 14     Thomas High School   Charter  1635  1043130

# %%
school_summary.columns=["name","School Type","Total Students","Total School Budget"]
school_summary
# Out:
#                      name School Type  Total Students  Total School Budget
# 0       Huang High School    District            2917              1910635
# 1    Figueroa High School    District            2949              1884411
# 2     Shelton High School     Charter            1761              1056600
# 3   Hernandez High School    District            4635              3022020
# 4     Griffin High School     Charter            1468               917500
# 5      Wilson High School     Charter            2283              1319574
# 6     Cabrera High School     Charter            1858              1081356
# 7      Bailey High School    District            4976              3124928
# 8      Holden High School     Charter             427               248087
# 9        Pena High School     Charter             962               585858
# 10     Wright High School     Charter            1800              1049400
# ...

# %%
#Budget per Student

school_summary["Per Student Budget"] = school_summary["Total School Budget"]/school_summary["Total Students"]
school_summary
# Out:
#                      name School Type  Total Students  Total School Budget  \
# 0       Huang High School    District            2917              1910635
# 1    Figueroa High School    District            2949              1884411
# 2     Shelton High School     Charter            1761              1056600
# 3   Hernandez High School    District            4635              3022020
# 4     Griffin High School     Charter            1468               917500
# 5      Wilson High School     Charter            2283              1319574
# 6     Cabrera High School     Charter            1858              1081356
# 7      Bailey High School    District            4976              3124928
# 8      Holden High School     Charter             427               248087
# 9        Pena High School     Charter             962               585858
# 10     Wright High School     Charter            1800              1049400
# ...

# %%
school_summary_clean = school_summary.set_index('name')
school_summary_clean
# Out:
#                       School Type  Total Students  Total School Budget  \
# name
# Huang High School        District            2917              1910635
# Figueroa High School     District            2949              1884411
# Shelton High School       Charter            1761              1056600
# Hernandez High School    District            4635              3022020
# Griffin High School       Charter            1468               917500
# Wilson High School        Charter            2283              1319574
# Cabrera High School       Charter            1858              1081356
# Bailey High School       District            4976              3124928
# Holden High School        Charter             427               248087
# Pena High School          Charter             962               585858
# Wright High School        Charter            1800              1049400
# Rodriguez High School    District            3999              2547363
# ...

# %%
#group school

group_school = student_df.groupby('school')
scores_per_school = group_school.sum()
scores_per_school
# Out:
#                        Student ID  reading_score  math_score
# school
# Bailey High School      101303896         403225      383393
# Cabrera High School      31477307         156027      154329
# Figueroa High School     12949059         239335      226223
# Ford High School         99055935         221164      211184
# Griffin High School      19077394         123043      122360
# Hernandez High School    46090440         375131      358238
# Holden High School        9846620          35789       35784
# Huang High School         4252986         236810      223528
# Johnson High School     154327815         385481      366942
# Pena High School         22851829          80851       80654
# Rodriguez High School   112111965         322898      307294
# Shelton High School      11879706         147441      146796
# Thomas High School       62705520         137093      136389
# Wilson High School       33950493         191748      190115
# ...

# %%
school_summary_x = pd.merge(school_summary_clean,scores_per_school, how='outer', left_index=True, right_index=True)
school_summary_x
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
school_summary_x["reading_score"]=school_summary_x["reading_score"]/school_summary_x["Total Students"]
school_summary_x
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
school_summary_x["math_score"]=school_summary_x["math_score"]/school_summary_x["Total Students"]
school_summary_x
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
school_summary_x = school_summary_x.drop('Student ID', axis=1)
school_summary_x
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
school_summary_x.columns=["School Type","Total Students","Total Budget","Per Student Budget","Average Reading Score","Average Math Score"]
school_summary_x
# Out:
#                       School Type  Total Students  Total Budget  \
# Bailey High School       District            4976       3124928
# Cabrera High School       Charter            1858       1081356
# Figueroa High School     District            2949       1884411
# Ford High School         District            2739       1763916
# Griffin High School       Charter            1468        917500
# Hernandez High School    District            4635       3022020
# Holden High School        Charter             427        248087
# Huang High School        District            2917       1910635
# Johnson High School      District            4761       3094650
# Pena High School          Charter             962        585858
# Rodriguez High School    District            3999       2547363
# Shelton High School       Charter            1761       1056600
# Thomas High School        Charter            1635       1043130
# Wilson High School        Charter            2283       1319574
# ...

# %%
pass_read_df = student_df.loc[(student_df["reading_score"] >= 70.0)]
pass_read_df
# Out:
#        Student ID                 name gender grade              school  \
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# 13             13         William Long      M   9th   Huang High School
# 14             14         Tammy Hebert      F  10th   Huang High School
# ...

# %%
group_read_pass = pass_read_df.groupby('school')
count_pass_read = group_read_pass.count()
count_pass_read
# Out:
#                        Student ID  name  gender  grade  reading_score  \
# school
# Bailey High School           4077  4077    4077   4077           4077
# Cabrera High School          1803  1803    1803   1803           1803
# Figueroa High School         2381  2381    2381   2381           2381
# Ford High School             2172  2172    2172   2172           2172
# Griffin High School          1426  1426    1426   1426           1426
# Hernandez High School        3748  3748    3748   3748           3748
# Holden High School            411   411     411    411            411
# Huang High School            2372  2372    2372   2372           2372
# Johnson High School          3867  3867    3867   3867           3867
# Pena High School              923   923     923    923            923
# Rodriguez High School        3208  3208    3208   3208           3208
# Shelton High School          1688  1688    1688   1688           1688
# ...

# %%
school_summary_x = school_summary_x.merge(count_pass_read, left_index=True, right_index=True)
school_summary_x
# Out:
#                       School Type  Total Students  Total Budget  \
# Bailey High School       District            4976       3124928
# Cabrera High School       Charter            1858       1081356
# Figueroa High School     District            2949       1884411
# Ford High School         District            2739       1763916
# Griffin High School       Charter            1468        917500
# Hernandez High School    District            4635       3022020
# Holden High School        Charter             427        248087
# Huang High School        District            2917       1910635
# Johnson High School      District            4761       3094650
# Pena High School          Charter             962        585858
# Rodriguez High School    District            3999       2547363
# Shelton High School       Charter            1761       1056600
# Thomas High School        Charter            1635       1043130
# Wilson High School        Charter            2283       1319574
# ...

# %%
school_summary_x=school_summary_x[["School Type","Total Students","Total Budget","Per Student Budget","Average Reading Score","Average Math Score","reading_score"]]
school_summary_x["reading_score"]=school_summary_x["reading_score"]/school_summary_x["Total Students"]
school_summary_x = school_summary_x.rename(columns ={'reading_score':'%Passing Reading'})
school_summary_x
# Out:
# C:\Users\gkchan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                       School Type  Total Students  Total Budget  \
# Bailey High School       District            4976       3124928
# Cabrera High School       Charter            1858       1081356
# Figueroa High School     District            2949       1884411
# Ford High School         District            2739       1763916
# Griffin High School       Charter            1468        917500
# Hernandez High School    District            4635       3022020
# Holden High School        Charter             427        248087
# Huang High School        District            2917       1910635
# ...

# %%
pass_math_df = student_df.loc[(student_df["math_score"] >= 70.0)]
pass_math_df
# Out:
#        Student ID                 name gender grade              school  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# 12             12      Brittney Walker      F   9th   Huang High School
# 13             13         William Long      M   9th   Huang High School
# 15             15    Dr. Jordan Carson      M  11th   Huang High School
# 17             17    Kimberly Santiago      F   9th   Huang High School
# ...

# %%
group_math_pass = pass_math_df.groupby('school')
count_math_read = group_math_pass.count()
count_math_read
# Out:
#                        Student ID  name  gender  grade  reading_score  \
# school
# Bailey High School           3318  3318    3318   3318           3318
# Cabrera High School          1749  1749    1749   1749           1749
# Figueroa High School         1946  1946    1946   1946           1946
# Ford High School             1871  1871    1871   1871           1871
# Griffin High School          1371  1371    1371   1371           1371
# Hernandez High School        3094  3094    3094   3094           3094
# Holden High School            395   395     395    395            395
# Huang High School            1916  1916    1916   1916           1916
# Johnson High School          3145  3145    3145   3145           3145
# Pena High School              910   910     910    910            910
# Rodriguez High School        2654  2654    2654   2654           2654
# Shelton High School          1653  1653    1653   1653           1653
# ...

# %%
school_summary_x = school_summary_x.merge(count_math_read, left_index=True, right_index=True)
school_summary_x
# Out:
#                       School Type  Total Students  Total Budget  \
# Bailey High School       District            4976       3124928
# Cabrera High School       Charter            1858       1081356
# Figueroa High School     District            2949       1884411
# Ford High School         District            2739       1763916
# Griffin High School       Charter            1468        917500
# Hernandez High School    District            4635       3022020
# Holden High School        Charter             427        248087
# Huang High School        District            2917       1910635
# Johnson High School      District            4761       3094650
# Pena High School          Charter             962        585858
# Rodriguez High School    District            3999       2547363
# Shelton High School       Charter            1761       1056600
# Thomas High School        Charter            1635       1043130
# Wilson High School        Charter            2283       1319574
# ...

# %%
school_summary_x=school_summary_x[["School Type","Total Students","Total Budget","Per Student Budget","Average Reading Score","Average Math Score","%Passing Reading","math_score"]]
school_summary_x["math_score"]=school_summary_x["math_score"]/school_summary_x["Total Students"]
school_summary_x = school_summary_x.rename(columns ={'math_score':'%Passing Math'})
school_summary_x
# Out:
# C:\Users\gkchan\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                       School Type  Total Students  Total Budget  \
# Bailey High School       District            4976       3124928
# Cabrera High School       Charter            1858       1081356
# Figueroa High School     District            2949       1884411
# Ford High School         District            2739       1763916
# Griffin High School       Charter            1468        917500
# Hernandez High School    District            4635       3022020
# Holden High School        Charter             427        248087
# Huang High School        District            2917       1910635
# ...

# %%
#this is the final School Summary

school_summary_x["Overall Passing Rate"]= (school_summary_x["%Passing Reading"]+school_summary_x["%Passing Math"])/2
school_summary_x
# Out:
#                       School Type  Total Students  Total Budget  \
# Bailey High School       District            4976       3124928
# Cabrera High School       Charter            1858       1081356
# Figueroa High School     District            2949       1884411
# Ford High School         District            2739       1763916
# Griffin High School       Charter            1468        917500
# Hernandez High School    District            4635       3022020
# Holden High School        Charter             427        248087
# Huang High School        District            2917       1910635
# Johnson High School      District            4761       3094650
# Pena High School          Charter             962        585858
# Rodriguez High School    District            3999       2547363
# Shelton High School       Charter            1761       1056600
# Thomas High School        Charter            1635       1043130
# Wilson High School        Charter            2283       1319574
# ...

# %%
#Top Performing Schools (By Passing Rate)

school_summary_max = school_summary_x.sort_values('Overall Passing Rate', ascending=False)
school_summary_max.head(5)
# Out:
#                     School Type  Total Students  Total Budget  \
# Cabrera High School     Charter            1858       1081356
# Thomas High School      Charter            1635       1043130
# Pena High School        Charter             962        585858
# Griffin High School     Charter            1468        917500
# Wilson High School      Charter            2283       1319574
#
#                      Per Student Budget  Average Reading Score  \
# Cabrera High School               582.0              83.975780
# Thomas High School                638.0              83.848930
# Pena High School                  609.0              84.044699
# Griffin High School               625.0              83.816757
# Wilson High School                578.0              83.989488
#
#                      Average Math Score  %Passing Reading  %Passing Math  \
# Cabrera High School           83.061895          0.970398       0.941335
# ...

# %%
#Bottom Performing Schools (By Passing Rate)

school_summary_min = school_summary_x.sort_values('Overall Passing Rate', ascending=True)
school_summary_min.head(5)
# Out:
#                       School Type  Total Students  Total Budget  \
# Rodriguez High School    District            3999       2547363
# Figueroa High School     District            2949       1884411
# Huang High School        District            2917       1910635
# Johnson High School      District            4761       3094650
# Ford High School         District            2739       1763916
#
#                        Per Student Budget  Average Reading Score  \
# Rodriguez High School               637.0              80.744686
# Figueroa High School                639.0              81.158020
# Huang High School                   655.0              81.182722
# Johnson High School                 650.0              80.966394
# Ford High School                    644.0              80.746258
#
#                        Average Math Score  %Passing Reading  %Passing Math  \
# Rodriguez High School           76.842711          0.802201       0.663666
# ...

# %%
#Math Scores by Grade

score_by_grade = student_df.groupby(['school','grade'])
score_by_grade = score_by_grade.mean()
score_by_grade
# Out:
#                                Student ID  reading_score  math_score
# school                grade
# Bailey High School    10th   20365.058918      80.907183   76.996772
#                       11th   20345.148681      80.945643   77.515588
#                       12th   20386.724708      80.912451   76.492218
#                       9th    20344.481481      81.303155   77.083676
# Cabrera High School   10th   16909.487124      84.253219   83.154506
#                       11th   16955.047718      83.788382   82.765560
#                       12th   16924.570681      84.287958   83.277487
#                       9th    16969.634470      83.676136   83.094697
# Figueroa High School  10th    4332.703801      81.408912   76.539974
#                       11th    4424.478138      80.640339   76.884344
#                       12th    4414.922705      81.384863   77.151369
#                       9th     4397.878505      81.198598   76.403037
# ...

# %%
#Math Scores by Grade (Final)

math_by_grade = score_by_grade["math_score"]
math_by_grade_df = math_by_grade.to_frame()
math_by_grade_df
# Out:
#                              math_score
# school                grade
# Bailey High School    10th    76.996772
#                       11th    77.515588
#                       12th    76.492218
#                       9th     77.083676
# Cabrera High School   10th    83.154506
#                       11th    82.765560
#                       12th    83.277487
#                       9th     83.094697
# Figueroa High School  10th    76.539974
#                       11th    76.884344
#                       12th    77.151369
#                       9th     76.403037
# Ford High School      10th    77.672316
#                       11th    76.918058
#                       12th    76.179963
#                       9th     77.361345
# Griffin High School   10th    84.229064
#                       11th    83.842105
#                       12th    83.356164
#                       9th     82.044010
# Hernandez High School 10th    77.337408
#                       11th    77.136029
# ...

# %%
#Reading Scores by Grade

read_by_grade = score_by_grade["reading_score"]
read_by_grade_df = read_by_grade.to_frame()
read_by_grade_df
# Out:
#                              reading_score
# school                grade
# Bailey High School    10th       80.907183
#                       11th       80.945643
#                       12th       80.912451
#                       9th        81.303155
# Cabrera High School   10th       84.253219
#                       11th       83.788382
#                       12th       84.287958
#                       9th        83.676136
# Figueroa High School  10th       81.408912
#                       11th       80.640339
#                       12th       81.384863
#                       9th        81.198598
# Ford High School      10th       81.262712
#                       11th       80.403642
#                       12th       80.662338
#                       9th        80.632653
# Griffin High School   10th       83.706897
#                       11th       84.288089
#                       12th       84.013699
#                       9th        83.369193
# ...

# %%
#Scores by School Spending per Student
#create bins

bins=[0,585,615,645,675]
group_names = ['<$585','$585-$615',"$615 to $645","$645 to $675"]

school_summary_x["Spending Level"] = pd.cut(school_summary_x["Per Student Budget"], bins, labels = group_names)
school_summary_x
# Out:
#                       School Type  Total Students  Total Budget  \
# Bailey High School       District            4976       3124928
# Cabrera High School       Charter            1858       1081356
# Figueroa High School     District            2949       1884411
# Ford High School         District            2739       1763916
# Griffin High School       Charter            1468        917500
# Hernandez High School    District            4635       3022020
# Holden High School        Charter             427        248087
# Huang High School        District            2917       1910635
# Johnson High School      District            4761       3094650
# Pena High School          Charter             962        585858
# Rodriguez High School    District            3999       2547363
# Shelton High School       Charter            1761       1056600
# Thomas High School        Charter            1635       1043130
# Wilson High School        Charter            2283       1319574
# ...

# %%
score_by_spending = school_summary_x.groupby(['Spending Level'])
score_by_spending = score_by_spending.mean()
score_by_spending =score_by_spending[['Average Reading Score','Average Math Score','%Passing Math','%Passing Reading','Overall Passing Rate']]
score_by_spending
# Out:
#                 Average Reading Score  Average Math Score  %Passing Math  \
# Spending Level
# <$585                       83.933814           83.455399       0.934601
# $585-$615                   83.885211           83.599686       0.942309
# $615 to $645                81.891436           79.079225       0.756682
# $645 to $675                81.027843           76.997210       0.661648
#
#                 %Passing Reading  Overall Passing Rate
# Spending Level
# <$585                   0.966109              0.950355
# $585-$615               0.959003              0.950656
# $615 to $645            0.861066              0.808874
# $645 to $675            0.811340              0.736494

# %%
#Scores by School Size
#create bins (sall, meadium, large)

bin_size = [0,1000,2000,5000]
label_size = ["Small(<1000)","Medium(1000-2000)","Large(2000-5000)"]


school_summary_x["Size Group"] = pd.cut(school_summary_x["Total Students"], bin_size, label_size)
school_summary_x
# Out:
#                       School Type  Total Students  Total Budget  \
# Bailey High School       District            4976       3124928
# Cabrera High School       Charter            1858       1081356
# Figueroa High School     District            2949       1884411
# Ford High School         District            2739       1763916
# Griffin High School       Charter            1468        917500
# Hernandez High School    District            4635       3022020
# Holden High School        Charter             427        248087
# Huang High School        District            2917       1910635
# Johnson High School      District            4761       3094650
# Pena High School          Charter             962        585858
# Rodriguez High School    District            3999       2547363
# Shelton High School       Charter            1761       1056600
# Thomas High School        Charter            1635       1043130
# Wilson High School        Charter            2283       1319574
# ...

# %%
score_by_size = school_summary_x.groupby(['Size Group'])
score_by_size = score_by_size.mean()
score_by_size =score_by_size[['Average Math Score','Average Reading Score','%Passing Math','%Passing Reading','Overall Passing Rate']]
score_by_size
# Out:
#               Average Math Score  Average Reading Score  %Passing Math  \
# Size Group
# (0, 1000]              83.821598              83.929843       0.935502
# (1000, 2000]           83.374684              83.864438       0.935997
# (2000, 5000]           77.746417              81.344493       0.699634
#
#               %Passing Reading  Overall Passing Rate
# Size Group
# (0, 1000]             0.960994              0.948248
# (1000, 2000]          0.967907              0.951952
# (2000, 5000]          0.827666              0.763650

# %%
score_by_type = school_summary_x.groupby(['School Type'])
score_by_type = score_by_type.mean()
score_by_type =score_by_type[['Average Math Score','Average Reading Score','%Passing Math','%Passing Reading','Overall Passing Rate']]
score_by_type
# Out:
#              Average Math Score  Average Reading Score  %Passing Math  \
# School Type
# Charter               83.473852              83.896421       0.936208
# District              76.956733              80.966636       0.665485
#
#              %Passing Reading  Overall Passing Rate
# School Type
# Charter              0.965865              0.951037
# District             0.807991              0.736738
